# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\windows\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\windows\anaconda3\lib\site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\windows\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\windows\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\windows\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\windows\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
df = pd.read_csv("telecom_churn_clean.csv")

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      tenureGroup PhoneService     MultipleLines InternetService  ...  \
# 0       0-1 Year           No  No phone service             DSL  ...
# 1      2-4 Years          Yes                No             DSL  ...
# 2       0-1 Year          Yes                No             DSL  ...
# 3      2-4 Years           No  No phone service             DSL  ...
# 4       0-1 Year          Yes                No     Fiber optic  ...
# ...          ...          ...               ...             ...  ...
# 7038   1-2 Years          Yes               Yes             DSL  ...
# 7039    4+ Years          Yes               Yes     Fiber optic  ...
# 7040    0-1 Year           No  No phone service             DSL  ...
# 7041    0-1 Year          Yes               Yes     Fiber optic  ...
# 7042    4+ Years          Yes                No     Fiber optic  ...
#
#      StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No              No  Month-to-month              Yes
# 1             No              No        One year               No
# 2             No              No  Month-to-month              Yes
# 3             No              No        One year               No
# 4             No              No  Month-to-month              Yes
# ...          ...             ...             ...              ...
# 7038         Yes             Yes        One year              Yes
# 7039         Yes             Yes        One year              Yes
# 7040          No              No  Month-to-month              Yes
# 7041          No              No  Month-to-month              Yes
# 7042         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges HighValueCustomer TotalCharges  \
# 0              Electronic check          29.85          Standard        29.85
# 1                  Mailed check          56.95          Standard      1889.50
# 2                  Mailed check          53.85          Standard       108.15
# 3     Bank transfer (automatic)          42.30          Standard      1840.75
# 4              Electronic check          70.70          Standard       151.65
# ...                         ...            ...               ...          ...
# 7038               Mailed check          84.80        High Value      1990.50
# 7039    Credit card (automatic)         103.20        High Value      7362.90
# 7040           Electronic check          29.60          Standard       346.45
# 7041               Mailed check          74.40          Standard       306.60
# 7042  Bank transfer (automatic)         105.65        High Value      6844.50
#
#      CleanedTotalCharges  Churn
# 0                  29.85     No
# 1                1889.50     No
# 2                 108.15    Yes
# 3                1840.75     No
# 4                 151.65    Yes
# ...                  ...    ...
# 7038             1990.50     No
# 7039             7362.90     No
# 7040              346.45     No
# 7041              306.60    Yes
# 7042             6844.50     No
#
# [7043 rows x 24 columns]

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure tenureGroup  \
# 0  7590-VHVEG  Female              0     Yes         No       1    0-1 Year
# 1  5575-GNVDE    Male              0      No         No      34   2-4 Years
# 2  3668-QPYBK    Male              0      No         No       2    0-1 Year
# 3  7795-CFOCW    Male              0      No         No      45   2-4 Years
# 4  9237-HQITU  Female              0      No         No       2    0-1 Year
#
#   PhoneService     MultipleLines InternetService  ... StreamingTV  \
# 0           No  No phone service             DSL  ...          No
# 1          Yes                No             DSL  ...          No
# 2          Yes                No             DSL  ...          No
# 3           No  No phone service             DSL  ...          No
# 4          Yes                No     Fiber optic  ...          No
#
#   StreamingMovies        Contract PaperlessBilling              PaymentMethod  \
# 0              No  Month-to-month              Yes           Electronic check
# 1              No        One year               No               Mailed check
# 2              No  Month-to-month              Yes               Mailed check
# 3              No        One year               No  Bank transfer (automatic)
# 4              No  Month-to-month              Yes           Electronic check
#
#   MonthlyCharges HighValueCustomer TotalCharges CleanedTotalCharges  Churn
# 0          29.85          Standard        29.85               29.85     No
# 1          56.95          Standard      1889.50             1889.50     No
# 2          53.85          Standard       108.15              108.15    Yes
# 3          42.30          Standard      1840.75             1840.75     No
# 4          70.70          Standard       151.65              151.65    Yes
#
# [5 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 24 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customerID           7043 non-null   object
#  1   gender               7043 non-null   object
#  2   SeniorCitizen        7043 non-null   int64
#  3   Partner              7043 non-null   object
#  4   Dependents           7043 non-null   object
#  5   tenure               7043 non-null   int64
#  6   tenureGroup          7043 non-null   object
#  7   PhoneService         7043 non-null   object
#  8   MultipleLines        7043 non-null   object
#  9   InternetService      7043 non-null   object
#  10  OnlineSecurity       7043 non-null   object
#  11  OnlineBackup         7043 non-null   object
#  12  DeviceProtection     7043 non-null   object
#  13  TechSupport          7043 non-null   object
#  14  StreamingTV          7043 non-null   object
#  15  StreamingMovies      7043 non-null   object
#  16  Contract             7043 non-null   object
#  17  PaperlessBilling     7043 non-null   object
#  18  PaymentMethod        7043 non-null   object
#  19  MonthlyCharges       7043 non-null   float64
#  20  HighValueCustomer    7043 non-null   object
#  21  TotalCharges         7032 non-null   float64
#  22  CleanedTotalCharges  7043 non-null   float64
#  23  Churn                7043 non-null   object
# dtypes: float64(3), int64(2), object(19)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges  \
# count    7043.000000  7043.000000     7043.000000   7032.000000
# mean        0.162147    32.370013       64.761692   2283.300441
# std         0.368612    24.560955       30.090047   2266.771362
# min         0.000000     0.000000       18.250000     18.800000
# 25%         0.000000     9.000000       35.500000    401.450000
# 50%         0.000000    29.000000       70.350000   1397.475000
# 75%         0.000000    55.000000       89.850000   3794.737500
# max         1.000000    72.000000      118.750000   8684.800000
#
#        CleanedTotalCharges
# count          7043.000000
# mean           2279.665491
# std            2266.862669
# min               0.000000
# 25%             398.550000
# 50%            1394.550000
# 75%            3786.600000
# max            8684.800000

# %%
df.describe(include='all')
# Out:
#         customerID gender  SeniorCitizen Partner Dependents       tenure  \
# count         7043   7043    7043.000000    7043       7043  7043.000000
# unique        7043      2            NaN       2          2          NaN
# top     7590-VHVEG   Male            NaN      No         No          NaN
# freq             1   3555            NaN    3641       4933          NaN
# mean           NaN    NaN       0.162147     NaN        NaN    32.370013
# std            NaN    NaN       0.368612     NaN        NaN    24.560955
# min            NaN    NaN       0.000000     NaN        NaN     0.000000
# 25%            NaN    NaN       0.000000     NaN        NaN     9.000000
# 50%            NaN    NaN       0.000000     NaN        NaN    29.000000
# 75%            NaN    NaN       0.000000     NaN        NaN    55.000000
# max            NaN    NaN       1.000000     NaN        NaN    72.000000
#
#        tenureGroup PhoneService MultipleLines InternetService  ...  \
# count         7043         7043          7043            7043  ...
# unique           4            2             3               3  ...
# top       4+ Years          Yes            No     Fiber optic  ...
# freq          2239         6361          3390            3096  ...
# mean           NaN          NaN           NaN             NaN  ...
# std            NaN          NaN           NaN             NaN  ...
# min            NaN          NaN           NaN             NaN  ...
# 25%            NaN          NaN           NaN             NaN  ...
# 50%            NaN          NaN           NaN             NaN  ...
# 75%            NaN          NaN           NaN             NaN  ...
# max            NaN          NaN           NaN             NaN  ...
#
#        StreamingTV StreamingMovies        Contract PaperlessBilling  \
# count         7043            7043            7043             7043
# unique           3               3               3                2
# top             No              No  Month-to-month              Yes
# freq          2810            2785            3875             4171
# mean           NaN             NaN             NaN              NaN
# std            NaN             NaN             NaN              NaN
# min            NaN             NaN             NaN              NaN
# 25%            NaN             NaN             NaN              NaN
# 50%            NaN             NaN             NaN              NaN
# 75%            NaN             NaN             NaN              NaN
# max            NaN             NaN             NaN              NaN
#
#            PaymentMethod MonthlyCharges HighValueCustomer TotalCharges  \
# count               7043    7043.000000              7043  7032.000000
# unique                 4            NaN                 2          NaN
# top     Electronic check            NaN          Standard          NaN
# freq                2365            NaN              4366          NaN
# mean                 NaN      64.761692               NaN  2283.300441
# std                  NaN      30.090047               NaN  2266.771362
# min                  NaN      18.250000               NaN    18.800000
# 25%                  NaN      35.500000               NaN   401.450000
# 50%                  NaN      70.350000               NaN  1397.475000
# 75%                  NaN      89.850000               NaN  3794.737500
# max                  NaN     118.750000               NaN  8684.800000
#
#        CleanedTotalCharges  Churn
# count          7043.000000   7043
# unique                 NaN      2
# top                    NaN     No
# freq                   NaN   5174
# mean           2279.665491    NaN
# std            2266.862669    NaN
# min               0.000000    NaN
# 25%             398.550000    NaN
# 50%            1394.550000    NaN
# 75%            3786.600000    NaN
# max            8684.800000    NaN
#
# [11 rows x 24 columns]

# %%
df.isnull().sum()
# Out:
# customerID              0
# gender                  0
# SeniorCitizen           0
# Partner                 0
# Dependents              0
# tenure                  0
# tenureGroup             0
# PhoneService            0
# MultipleLines           0
# InternetService         0
# OnlineSecurity          0
# OnlineBackup            0
# DeviceProtection        0
# TechSupport             0
# StreamingTV             0
# StreamingMovies         0
# Contract                0
# PaperlessBilling        0
# PaymentMethod           0
# MonthlyCharges          0
# HighValueCustomer       0
# TotalCharges           11
# CleanedTotalCharges     0
# Churn                   0
# dtype: int64

# %%
df["TotalCharges"]=df.groupby('tenure')['TotalCharges'].transform(lambda x: x.fillna(x.median()))

# %%
df.isnull().sum()
# Out:
# customerID             0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# tenure                 0
# tenureGroup            0
# PhoneService           0
# MultipleLines          0
# InternetService        0
# OnlineSecurity         0
# OnlineBackup           0
# DeviceProtection       0
# TechSupport            0
# StreamingTV            0
# StreamingMovies        0
# Contract               0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# HighValueCustomer      0
# TotalCharges           0
# CleanedTotalCharges    0
# Churn                  0
# dtype: int64

# %%
df.columns=df.columns.str.lower()

# %%
df.columns
# Out:
# Index(['customerid', 'gender', 'seniorcitizen', 'partner', 'dependents',
#        'tenure', 'tenuregroup', 'phoneservice', 'multiplelines',
#        'internetservice', 'onlinesecurity', 'onlinebackup', 'deviceprotection',
#        'techsupport', 'streamingtv', 'streamingmovies', 'contract',
#        'paperlessbilling', 'paymentmethod', 'monthlycharges',
#        'highvaluecustomer', 'cleanedtotalcharges', 'churn'],
#       dtype='object')

# %%
df.columns=df.columns.str.title()

# %%
df.columns
# Out:
# Index(['Customerid', 'Gender', 'Seniorcitizen', 'Partner', 'Dependents',
#        'Tenure', 'Tenuregroup', 'Phoneservice', 'Multiplelines',
#        'Internetservice', 'Onlinesecurity', 'Onlinebackup', 'Deviceprotection',
#        'Techsupport', 'Streamingtv', 'Streamingmovies', 'Contract',
#        'Paperlessbilling', 'Paymentmethod', 'Monthlycharges',
#        'Highvaluecustomer', 'Totalcharges', 'Cleanedtotalcharges', 'Churn'],
#       dtype='object')

# %%
df=df.drop('Totalcharges',axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df=df.drop('Totalcharges',axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['Totalcharges'] not found in axis"

# %%
df.columns

# %%
# !pip install psycopg2-binary sqlalchemy
# Out:
# Requirement already satisfied: psycopg2-binary in c:\users\windows\anaconda3\lib\site-packages (2.9.12)
# Requirement already satisfied: sqlalchemy in c:\users\windows\anaconda3\lib\site-packages (2.0.43)
# Requirement already satisfied: greenlet>=1 in c:\users\windows\anaconda3\lib\site-packages (from sqlalchemy) (3.2.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\windows\anaconda3\lib\site-packages (from sqlalchemy) (4.15.0)

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

username = "postgres"
password = quote_plus("Lalitha@2026")   # 🔑 encode special characters
host = "localhost"
port = "5432"
database = "telecom_churn"

engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# Test connection
with engine.connect() as conn:
    print("Connected successfully!")

df.to_sql(
    "customer",
    engine,
    if_exists="replace",
    index=False
)

print("Data successfully loaded into PostgreSQL")
# Out:
# Connected successfully!
# Data successfully loaded into PostgreSQL
